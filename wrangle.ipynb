# %%
from wrangle import Wrangle

# %%
nutrition_facts = Wrangle().get_food_data()
nutrition_facts.head()
# Out:
#        ID                                               Name   Food Group  \
# 0  167512  Pillsbury Golden Layer Buttermilk Biscuits Art...  Baked Foods
# 1  167513  Pillsbury Cinnamon Rolls With Icing Refrigerat...  Baked Foods
# 2  167514  Kraft Foods Shake N Bake Original Recipe Coati...  Baked Foods
# 3  167515      George Weston Bakeries Thomas English Muffins  Baked Foods
# 4  167516              Waffles Buttermilk Frozen ReadyToHeat  Baked Foods
#
#    Calories  Fat g  Protein g  Carbohydrate g  Sugars g  Fiber g  \
# 0     307.0  13.24       5.88           41.18      5.88      1.2
# 1     330.0  11.27       4.34           53.42     21.34      1.4
# 2     377.0   3.70       6.10           79.80       NaN      NaN
# 3     232.0   1.80       8.00           46.00       NaN      NaN
# 4     273.0   9.22       6.58           41.05      4.30      2.2
#
#    Cholesterol mg  ...  Serving Weight 1 g  Serving Weight 2 g  \
# 0             0.0  ...                34.0                 NaN
# 1             0.0  ...                44.0                 NaN
# 2             NaN  ...                28.0                 NaN
# 3             NaN  ...                57.0                 NaN
# 4            15.0  ...                39.0                38.0
#
#    Serving Weight 3 g  Serving Weight 4 g  Serving Weight 5 g  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    Serving Weight 6 g  Serving Weight 7 g  Serving Weight 8 g  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    Serving Weight 9 g  200 Calorie Weight g
# 0                 NaN                65.147
# 1                 NaN                60.606
# 2                 NaN                53.050
# 3                 NaN                86.207
# 4                 NaN                73.260
#
# [5 rows x 108 columns]

# %%
nutrition_facts.isnull().sum().to_dict()
# Out:
# {'ID': 0,
#  'Name': 0,
#  'Food Group': 128,
#  'Calories': 0,
#  'Fat g': 0,
#  'Protein g': 0,
#  'Carbohydrate g': 0,
#  'Sugars g': 1786,
#  'Fiber g': 562,
#  'Cholesterol mg': 399,
#  'Saturated Fats g': 343,
#  'Calcium mg': 85,
#  'Iron Fe mg': 80,
#  'Potassium K mg': 277,
#  'Magnesium mg': 372,
#  'Vitamin A IU IU': 6808,
#  'Vitamin A RAE mcg': 875,
#  'Vitamin C mg': 461,
#  'Vitamin B12 mcg': 680,
#  'Vitamin D mcg': 2608,
#  'Vitamin E AlphaTocopherol mg': 2213,
#  'Added Sugar g': 14164,
#  'NetCarbs g': 0,
#  'Water g': 0,
#  'Omega 3s mg': 827,
#  'Omega 6s mg': 761,
#  'PRAL score': 415,
#  'Trans Fatty Acids g': 9985,
#  'Soluble Fiber g': 14164,
#  'Insoluble Fiber g': 14164,
#  'Sucrose g': 12431,
#  'Glucose Dextrose g': 12424,
#  'Fructose g': 12419,
#  'Lactose g': 12452,
#  'Maltose g': 12453,
#  'Galactose g': 12585,
#  'Starch g': 12997,
#  'Total sugar alcohols g': 14164,
#  'Phosphorus P mg': 326,
#  'Sodium mg': 84,
#  'Zinc Zn mg': 387,
#  'Copper Cu mg': 509,
#  'Manganese mg': 7672,
#  'Selenium Se mcg': 928,
#  'Fluoride F mcg': 13626,
#  'Molybdenum mcg': 14164,
#  'Chlorine mg': 14164,
#  'Thiamin B1 mg': 391,
#  'Riboflavin B2 mg': 372,
#  'Niacin B3 mg': 391,
#  'Pantothenic acid B5 mg': 7788,
#  'Vitamin B6 mg': 531,
#  'Biotin B7 mcg': 14164,
#  'Folate B9 mcg': 942,
#  'Folic acid mcg': 1293,
#  'Food Folate mcg': 1071,
#  'Folate DFE mcg': 1311,
#  'Choline mg': 3182,
#  'Betaine mg': 12073,
#  'Retinol mcg': 1005,
#  'Carotene beta mcg': 2353,
#  'Carotene alpha mcg': 2441,
#  'Lycopene mcg': 2479,
#  'Lutein + Zeaxanthin mcg': 2499,
#  'Vitamin D2 ergocalciferol mcg': 14026,
#  'Vitamin D3 cholecalciferol mcg': 12345,
#  'Vitamin D IU IU': 8983,
#  'Vitamin K mcg': 2739,
#  'Dihydrophylloquinone mcg': 12745,
#  'Menaquinone4 mcg': 13558,
#  'Fatty acids total monounsaturated mg': 516,
#  'Fatty acids total polyunsaturated mg': 514,
#  '183 n3 ccc ALA mg': 12197,
#  '205 n3 EPA mg': 1993,
#  '225 n3 DPA mg': 2037,
#  '226 n3 DHA mg': 2021,
#  'Tryptophan mg': 9134,
#  'Threonine mg': 9084,
#  'Isoleucine mg': 9080,
#  'Leucine mg': 9081,
#  'Lysine mg': 9067,
#  'Methionine mg': 9068,
#  'Cystine mg': 9234,
#  'Phenylalanine mg': 9085,
#  'Tyrosine mg': 9115,
#  'Valine mg': 9081,
#  'Arginine mg': 9094,
#  'Histidine mg': 9088,
#  'Alanine mg': 9139,
#  'Aspartic acid mg': 9292,
#  'Glutamic acid mg': 9135,
#  'Glycine mg': 9139,
#  'Proline mg': 9147,
#  'Serine mg': 9139,
#  'Hydroxyproline mg': 12733,
#  'Alcohol g': 2394,
#  'Caffeine mg': 2578,
#  'Theobromine mg': 2623,
#  'Serving Weight 1 g': 539,
#  'Serving Weight 2 g': 6066,
#  'Serving Weight 3 g': 10512,
#  'Serving Weight 4 g': 11588,
#  'Serving Weight 5 g': 12061,
#  'Serving Weight 6 g': 12660,
#  'Serving Weight 7 g': 13048,
#  'Serving Weight 8 g': 13395,
#  'Serving Weight 9 g': 13458,
#  '200 Calorie Weight g': 39}

# %%
(nutrition_facts.isnull().sum()/len(nutrition_facts)).to_dict()
# Out:
# {'ID': 0.0,
#  'Name': 0.0,
#  'Food Group': 0.009036995199096301,
#  'Calories': 0.0,
#  'Fat g': 0.0,
#  'Protein g': 0.0,
#  'Carbohydrate g': 0.0,
#  'Sugars g': 0.12609432363739057,
#  'Fiber g': 0.039678057046032195,
#  'Cholesterol mg': 0.028170008472183,
#  'Saturated Fats g': 0.02421632307257837,
#  'Calcium mg': 0.006001129624399887,
#  'Iron Fe mg': 0.005648121999435188,
#  'Potassium K mg': 0.01955662242304434,
#  'Magnesium mg': 0.026263767297373623,
#  'Vitamin A IU IU': 0.4806551821519345,
#  'Vitamin A RAE mcg': 0.061776334368822364,
#  'Vitamin C mg': 0.03254730302174527,
#  'Vitamin B12 mcg': 0.048009036995199095,
#  'Vitamin D mcg': 0.18412877718158713,
#  'Vitamin E AlphaTocopherol mg': 0.15624117480937588,
#  'Added Sugar g': 1.0,
#  'NetCarbs g': 0.0,
#  'Water g': 0.0,
#  'Omega 3s mg': 0.058387461169161256,
#  'Omega 6s mg': 0.05372776051962722,
#  'PRAL score': 0.029299632872070037,
#  'Trans Fatty Acids g': 0.7049562270545043,
#  'Soluble Fiber g': 1.0,
#  'Insoluble Fiber g': 1.0,
#  'Sucrose g': 0.8776475571872352,
#  'Glucose Dextrose g': 0.8771533465122847,
#  'Fructose g': 0.87680033888732,
#  'Lactose g': 0.879130189212087,
#  'Maltose g': 0.8792007907370799,
#  'Galactose g': 0.888520192036148,
#  'Starch g': 0.9176080203332392,
#  'Total sugar alcohols g': 1.0,
#  'Phosphorus P mg': 0.02301609714769839,
#  'Sodium mg': 0.005930528099406947,
#  'Zinc Zn mg': 0.02732279017226772,
#  'Copper Cu mg': 0.03593617622140638,
#  'Manganese mg': 0.5416548997458345,
#  'Selenium Se mcg': 0.06551821519344818,
#  'Fluoride F mcg': 0.9620163795537984,
#  'Molybdenum mcg': 1.0,
#  'Chlorine mg': 1.0,
#  'Thiamin B1 mg': 0.02760519627223948,
#  'Riboflavin B2 mg': 0.026263767297373623,
#  'Niacin B3 mg': 0.02760519627223948,
#  'Pantothenic acid B5 mg': 0.5498446766450156,
#  'Vitamin B6 mg': 0.03748940977125106,
#  'Biotin B7 mcg': 1.0,
#  'Folate B9 mcg': 0.06650663654334933,
#  'Folic acid mcg': 0.09128777181587122,
#  'Food Folate mcg': 0.07561423326743857,
#  'Folate DFE mcg': 0.09255859926574414,
#  'Choline mg': 0.2246540525275346,
#  'Betaine mg': 0.8523722112397628,
#  'Retinol mcg': 0.07095453261790455,
#  'Carotene beta mcg': 0.16612538830838747,
#  'Carotene alpha mcg': 0.17233832250776618,
#  'Lycopene mcg': 0.17502118045749787,
#  'Lutein + Zeaxanthin mcg': 0.17643321095735667,
#  'Vitamin D2 ergocalciferol mcg': 0.9902569895509743,
#  'Vitamin D3 cholecalciferol mcg': 0.8715758260378424,
#  'Vitamin D IU IU': 0.6342134990115786,
#  'Vitamin K mcg': 0.19337757695566224,
#  'Dihydrophylloquinone mcg': 0.8998164360350184,
#  'Menaquinone4 mcg': 0.9572154758542785,
#  'Fatty acids total monounsaturated mg': 0.03643038689635696,
#  'Fatty acids total polyunsaturated mg': 0.03628918384637108,
#  '183 n3 ccc ALA mg': 0.8611268003388873,
#  '205 n3 EPA mg': 0.14070883931092912,
#  '225 n3 DPA mg': 0.14381530641061846,
#  '226 n3 DHA mg': 0.14268568201073142,
#  'Tryptophan mg': 0.6448743292855126,
#  'Threonine mg': 0.6413442530358656,
#  'Isoleucine mg': 0.6410618469358939,
#  'Leucine mg': 0.6411324484608868,
#  'Lysine mg': 0.6401440271109856,
#  'Methionine mg': 0.6402146286359786,
#  'Cystine mg': 0.6519344817848065,
#  'Phenylalanine mg': 0.6414148545608586,
#  'Tyrosine mg': 0.6435329003106467,
#  'Valine mg': 0.6411324484608868,
#  'Arginine mg': 0.6420502682857949,
#  'Histidine mg': 0.6416266591358374,
#  'Alanine mg': 0.6452273369104773,
#  'Aspartic acid mg': 0.6560293702343971,
#  'Glutamic acid mg': 0.6449449308105055,
#  'Glycine mg': 0.6452273369104773,
#  'Proline mg': 0.6457921491104208,
#  'Serine mg': 0.6452273369104773,
#  'Hydroxyproline mg': 0.8989692177351031,
#  'Alcohol g': 0.16902005083309798,
#  'Caffeine mg': 0.18201073143179894,
#  'Theobromine mg': 0.18518780005648122,
#  'Serving Weight 1 g': 0.038054221971194575,
#  'Serving Weight 2 g': 0.4282688506071731,
#  'Serving Weight 3 g': 0.7421632307257837,
#  'Serving Weight 4 g': 0.818130471618187,
#  'Serving Weight 5 g': 0.8515249929398475,
#  'Serving Weight 6 g': 0.8938153064106185,
#  'Serving Weight 7 g': 0.9212086981078791,
#  'Serving Weight 8 g': 0.9457074272804292,
#  'Serving Weight 9 g': 0.9501553233549844,
#  '200 Calorie Weight g': 0.002753459474724654}
